# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('data/spam.tsv',sep='\t')
data
# Out:
#      label                                            message  length  punct
# 0      ham  Go until jurong point, crazy.. Available only ...     111      9
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# ...    ...                                                ...     ...    ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [5572 rows x 4 columns]

# %%
data1=data.drop(['length','punct'],axis=1)

# %%
data1
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
data['length']=data.message.apply(len)

# %%
data
# Out:
#      label                                            message  length  punct
# 0      ham  Go until jurong point, crazy.. Available only ...     111      9
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# ...    ...                                                ...     ...    ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160      8
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5570   ham  The guy did some bitching but I acted like i'd...     125      1
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [5572 rows x 4 columns]

# %%
data1['length']=data1.message.apply(len)

# %%
data1
# Out:
#      label                                            message  length
# 0      ham  Go until jurong point, crazy.. Available only ...     111
# 1      ham                      Ok lar... Joking wif u oni...      29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3      ham  U dun say so early hor... U c already then say...      49
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61
# ...    ...                                                ...     ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...     160
# 5568   ham               Will ü b going to esplanade fr home?      36
# 5569   ham  Pity, * was in mood for that. So...any other s...      57
# 5570   ham  The guy did some bitching but I acted like i'd...     125
# 5571   ham                         Rofl. Its true to its name      26
#
# [5572 rows x 3 columns]

# %%
data.loc[data['length']>200]
# Out:
#      label                                            message  length  punct
# 53     ham  Wow. I never realized that you were so embaras...     289     14
# 127    ham  Just so that you know,yetunde hasn't sent mone...     244      9
# 155    ham  You are everywhere dirt, on the floor, the win...     384     16
# 334    ham  Any chance you might have had with me evaporat...     232      4
# 356    ham  Thank You for calling.Forgot to say Happy Onam...     202      7
# ...    ...                                                ...     ...    ...
# 5374   ham  Do u konw waht is rael FRIENDSHIP Im gving yuo...     212     13
# 5451   ham  Just sing HU. I think its also important to fi...     251      4
# 5515   ham  You are a great role model. You are giving so ...     245      5
# 5535   ham  I know you are thinkin malaria. But relax, chi...     329      6
# 5557   ham  No. I meant the calculation is the same. That ...     273     18
#
# [113 rows x 4 columns]

# %%
data.loc[data['length']<100]
# Out:
#      label                                            message  length  punct
# 1      ham                      Ok lar... Joking wif u oni...      29      6
# 3      ham  U dun say so early hor... U c already then say...      49      6
# 4      ham  Nah I don't think he goes to usf, he lives aro...      61      2
# 6      ham  Even my brother is not like to speak with me. ...      77      2
# 14     ham                I HAVE A DATE ON SUNDAY WITH WILL!!      35      2
# ...    ...                                                ...     ...    ...
# 5564   ham  Why don't you wait 'til at least wednesday to ...      67      3
# 5565   ham                                       Huh y lei...      12      3
# 5568   ham               Will ü b going to esplanade fr home?      36      1
# 5569   ham  Pity, * was in mood for that. So...any other s...      57      7
# 5571   ham                         Rofl. Its true to its name      26      1
#
# [3798 rows x 4 columns]

# %% [markdown]
# ## Text preprocessing

# %%
data.label.unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
data1['label'].map({'ham': 1,'spam': 0})
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 5567    0
# 5568    1
# 5569    1
# 5570    1
# 5571    1
# Name: label, Length: 5572, dtype: int64

# %%
data.label
# Out:
# 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: label, Length: 5572, dtype: object

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ## remove punctuation

# %%
def remove_punc(text):
    test="".join([char for char in text if char not in string.punctuation])
    return text

# %%
data1['text-clean']=data1['message'].apply(lambda x: remove_punc(x))

# %%
data1
# Out:
#      label                                            message  \
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
#                                              text-clean
# 0     Go until jurong point, crazy.. Available only ...
# 1                         Ok lar... Joking wif u oni...
# ...

# %%
data1['text-clean'].apply(len)
# Out:
# 0       111
# 1        29
# 2       155
# 3        49
# 4        61
#        ...
# 5567    160
# 5568     36
# 5569     57
# 5570    125
# 5571     26
# Name: text-clean, Length: 5572, dtype: int64

# %%
data1.label.unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
data1.label=data.label.map({'ham':1,'spam':0})

# %%
X=data1['text-clean']
y=data1['label']

# %%
y.dtype
# Out:
# dtype('int64')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=10)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(stop_words="english")
X_train_cv=cv.fit_transform(X_train)

# %%
X_test_cv=cv.transform(X_test)

# %% [markdown]
# ## model

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model1=MultinomialNB()
model1.fit(X_train_cv,y_train)
# Out:
# MultinomialNB()

# %%
y_pred=model1.predict(X_test_cv)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92       143
#            1       0.98      0.99      0.99       972
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.94      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
msg=input("enter message")
msg_input=cv.transform([msg])
predict=model.predict(msg_input)
if(predict[0]==0):
    print('Spam')
else:
    print('Ham')
# Out:
# Ham

# %% [markdown]
# ## TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
X_tf=tf.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_tf,y,test_size=0.20,random_state=10)

# %% [markdown]
# ## model

# %%
from sklearn.naive_bayes import BernoulliNB
model2=BernoulliNB()
model2.fit(X_train,y_train)
y_pred=model2.predict(X_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.91       143
#            1       0.98      1.00      0.99       972
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.92      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
with open('model1.pkl', 'wb') as f:
    pickle.dump((model1, cv), f)
